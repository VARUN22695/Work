# %%
import requests
from bs4 import BeautifulSoup

# URL of the website you want to scrape
url = 'https://en.wikipedia.org/wiki/N._T._Rama_Rao_Jr.'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the elements you want to scrape
    # For example, let's find all <a> tags with class 'link'
    links = soup.find_all('a', class_='link')

    # Print out the text of each link
    for link in links:
        print(link.text)
else:
    print('Failed to retrieve the webpage')

# %%
link.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cc5b3c76c7a8> in <cell line: 1>()
# ----> 1 link.text
#
# NameError: name 'link' is not defined

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website you want to scrape
url = 'https://en.wikipedia.org/wiki/Main_Page'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the elements you want to scrape
    # For example, let's find all <a> tags with class 'internal'
    links = soup.find_all('a', class_='internal')

    # Print out the text of each link
    for link in links:
        print(link.text)
else:
    print('Failed to retrieve the webpage')

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website you want to scrape
url = 'https://en.wikipedia.org/wiki/Main_Page'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the elements you want to scrape
    # For example, let's find all <a> tags with class 'internal'
    links = soup.find_all('a', class_='internal')

    # Print out the text of each link
    for link in links:
        print(link.text)
else:
    print('Failed to retrieve the webpage')

# %%
# !pip install requests
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website you want to scrape
url = 'https://en.wikipedia.org/wiki/Main_Page'

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the elements you want to scrape
    # For example, let's find all <a> tags with class 'internal'
    links = soup.find_all('a', class_='internal')

    # Print out the text of each link
    for link in links:
        print(link.text)
else:
    print('Failed to retrieve the webpage')

# %%
print(links)
# Out:
# []

# %%
l.text
# Out:
# 'https://en.wikipedia.org/wiki/Main_Page'

# %%
print(l.text)
# Out:
# https://en.wikipedia.org/wiki/Main_Page

# %%
link = BeautifulSoup('<a href="https://www.example.com">Example</a>', 'html.parser')

# %%
link.text
# Out:
# 'Example'

# %%
df.head(5)
# Out:
# Empty DataFrame
# Columns: [Links]
# Index: []

# %%
# !pip install beautifulsoup4
# !pip install requests

# %%
from bs4 import BeautifulSoup

# %%
req=requests.get("https://en.wikipedia.org/wiki/N._T._Rama_Rao_Jr.")

# %%
 soup=BeautifulSoup(req.content,.parse"htmlr")

# %%
res=soup.title

# %%
print(res.get_text())
# Out:
# N. T. Rama Rao Jr. - Wikipedia

# %%
print(res.prettify())
# Out:
# <title>
#  N. T. Rama Rao Jr. - Wikipedia
# </title>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-night-mode-clientpref-0 vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    N. T. Rama Rao Jr. - Wikipedia
#   </title>
#   <script>
# ...

# %%
print(soup.get_text())
# Out:
# N. T. Rama Rao Jr. - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
# Languages
#
# Language links are at the top of the page.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
#  Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1Early life and family
#
#
#
#
#
#
#
# 2Film career
#
#
#
# Toggle Film career subsection
#
#
#
#
#
# ...

# %%
re=soup.body

# %%
print(re.get_text())
# Out:
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
# Languages
#
# Language links are at the top of the page.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
#  Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1Early life and family
#
#
#
#
#
#
#
# 2Film career
#
#
#
# Toggle Film career subsection
#
#
#
#
#
# 2.11991–2006: Debut and initial career
#
#
#
#
#
#
#
# 2.22007–2012: Breakthrough and career fluctuations
#
# ...

# %%
soup.head.get_text()
# Out:
# '\n\nN. T. Rama Rao Jr. - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'
